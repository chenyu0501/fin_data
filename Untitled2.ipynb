# %%
import os
import pandas as pd 
import numpy as np

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
os.environ['TEJAPI_KEY'] = "btEQCjKJI9SAvQ3VDuyYXiQLXH4WhW"
os.environ['TEJAPI_BASE'] = "https://api.tej.com.tw"

# %%
start = '2021-01-01'
end = '2023-12-31'
from zipline.sources.TEJ_Api_Data import get_universe
# 抓取台灣50指數的股票

#StockList = get_universe(start, end, mkt = 'TWSE', stktp_c = '普通股', main_ind_c=['M2300 電子工業','OTC23 OTC 電子類'])
StockList=['2330','2454','2455','2458','3014','3034','3529','4952','4961','5234','6183','6531','6756','6799','8016','8081','8261']
#StockList=['2330']
tickers = ' '.join(StockList)
os.environ['ticker'] =tickers+' IX0001'
os.environ['mdate'] = start+' '+end

# calendar------------------------------------------
calendar_name = 'TEJ_XTAI'  
# bundle_name---------------------------------------
bundle_name = 'tquant'

# !zipline ingest -b tquant
# Out:
# Merging daily equity files:
# Currently used TEJ API key call quota 9/1000 (0.9%)
# Currently used TEJ API key data quota 40348/10000000 (0.4%)
# [2024-06-10 17:52:08.167430] INFO: zipline.data.bundles.core: Ingesting tquant.
# [2024-06-10 17:52:15.752421] INFO: zipline.data.bundles.core: Ingest tquant successfully.

# %%
from zipline.data import bundles
from zipline.utils.calendar_utils import get_calendar
from zipline.sources.TEJ_Api_Data import get_Benchmark_Return

bundle = bundles.load('tquant')
benchmark_asset = bundle.asset_finder.lookup_symbol('IX0001',as_of_date = None)
# 取所有sid
sids = bundle.asset_finder.equities_sids
# 取所有assets
assets = bundle.asset_finder.retrieve_all(sids)
# 取所有symbol
symbol = [i.symbol for i in assets]
# 用sid取assets
_asset = bundle.asset_finder.retrieve_equities([0,1])

# %%
from zipline.pipeline import Pipeline
from zipline.pipeline.data import TWEquityPricing
from zipline.TQresearch.tej_pipeline import run_pipeline   
from zipline.pipeline.factors import SimpleMovingAverage, RSI
def make_pipeline(short,long):
    rsi_long = RSI(inputs = [TWEquityPricing.close], window_length = long)
    rsi_short = RSI(inputs = [TWEquityPricing.close], window_length = short)
    return Pipeline(columns={'curr_price':TWEquityPricing.close.latest,
                             "RSI_short": rsi_short,
                             "RSI_long": rsi_long
                             
                            }
                   )

start_date = pd.Timestamp('2021-01-22',tz='utc')
end_date = pd.Timestamp('2023-12-31',tz='utc')
result = run_pipeline(make_pipeline(7,14), start_date, end_date)

result
# Out:
#                                                curr_price  RSI_short  \
# 2021-01-22 00:00:00+00:00 Equity(0 [2330])         673.00  86.170213
#                           Equity(1 [2454])         934.00  67.361111
#                           Equity(2 [2455])         114.00  37.500000
#                           Equity(3 [2458])         168.50  52.272727
#                           Equity(4 [3014])          75.70  60.818713
# ...                                                   ...        ...
# 2023-12-29 00:00:00+00:00 Equity(13 [6799])        194.00  83.529412
#                           Equity(14 [8016])        276.00  44.000000
#                           Equity(15 [8081])        266.00  75.000000
#                           Equity(16 [8261])         97.20  46.153846
#                           Equity(17 [IX0001])    17910.37  80.034491
#
#                                                 RSI_long
# 2021-01-22 00:00:00+00:00 Equity(0 [2330])     92.024540
#                           Equity(1 [2454])     77.734375
#                           Equity(2 [2455])     43.333333
#                           Equity(3 [2458])     78.787879
#                           Equity(4 [3014])     64.372470
# ...                                                  ...
# 2023-12-29 00:00:00+00:00 Equity(13 [6799])    72.727273
#                           Equity(14 [8016])    31.914894
#                           Equity(15 [8081])    55.639098
#                           Equity(16 [8261])    26.923077
#                           Equity(17 [IX0001])  78.290919
#
# [12557 rows x 3 columns]

# %%
result['pre_RSI_short']=result['RSI_short'].shift(17)
result['pre_RSI_long']=result['RSI_long'].shift(17)
result
# Out:
#                                                curr_price  RSI_short  \
# 2021-01-22 00:00:00+00:00 Equity(0 [2330])         673.00  86.170213
#                           Equity(1 [2454])         934.00  67.361111
#                           Equity(2 [2455])         114.00  37.500000
#                           Equity(3 [2458])         168.50  52.272727
#                           Equity(4 [3014])          75.70  60.818713
# ...                                                   ...        ...
# 2023-12-29 00:00:00+00:00 Equity(13 [6799])        194.00  83.529412
#                           Equity(14 [8016])        276.00  44.000000
#                           Equity(15 [8081])        266.00  75.000000
#                           Equity(16 [8261])         97.20  46.153846
#                           Equity(17 [IX0001])    17910.37  80.034491
#
#                                                 RSI_long  pre_RSI_short  \
# 2021-01-22 00:00:00+00:00 Equity(0 [2330])     92.024540            NaN
#                           Equity(1 [2454])     77.734375            NaN
#                           Equity(2 [2455])     43.333333            NaN
#                           Equity(3 [2458])     78.787879            NaN
#                           Equity(4 [3014])     64.372470            NaN
# ...                                                  ...            ...
# 2023-12-29 00:00:00+00:00 Equity(13 [6799])    72.727273      50.000000
#                           Equity(14 [8016])    31.914894      51.515152
#                           Equity(15 [8081])    55.639098      43.902439
#                           Equity(16 [8261])    26.923077      81.629743
#                           Equity(17 [IX0001])  78.290919      65.384615
#
#                                                pre_RSI_long
# 2021-01-22 00:00:00+00:00 Equity(0 [2330])              NaN
#                           Equity(1 [2454])              NaN
#                           Equity(2 [2455])              NaN
#                           Equity(3 [2458])              NaN
#                           Equity(4 [3014])              NaN
# ...                                                     ...
# 2023-12-29 00:00:00+00:00 Equity(13 [6799])       36.363636
#                           Equity(14 [8016])       40.404040
#                           Equity(15 [8081])       39.344262
#                           Equity(16 [8261])       78.670614
#                           Equity(17 [IX0001])     76.188117
#
# [12557 rows x 5 columns]

# %%
from zipline.finance import slippage, commission
from zipline.api import set_slippage, set_commission, set_benchmark, attach_pipeline, order, order_target, symbol, pipeline_output, record

def initialize(context):
    set_slippage(slippage.VolumeShareSlippage())
    set_commission(commission.PerShare(cost = 0.001425 + 0.003 / 2))
    attach_pipeline(make_pipeline(7, 14), 'mystrats')
    set_benchmark(symbol('IX0001'))

# %%
def handle_data(context, data):
    out_dir = pipeline_output('mystrats')
    out_dir['pre_RSI_short']=out_dir['RSI_short'].shift(17)
    out_dir['pre_RSI_long']=out_dir['RSI_long'].shift(17)
    out_dir[18:]
    for i in out_dir.index:
        sym = i.symbol
        RSI_short = out_dir.loc[i, 'RSI_short']
        RSI_long = out_dir.loc[i, "RSI_long"]
        pre_RSI_short = out_dir.loc[i, 'pre_RSI_short']
        pre_RSI_long = out_dir.loc[i, "pre_RSI_long"]
        curr_price = out_dir.loc[i, 'curr_price']
        
        cash_position = context.portfolio.cash    # 記錄現金水位
        stock_position = context.portfolio.positions[i].amount    # 記錄股票部位

        buy, sell = False, False

        record(
           **{
                f'price_{sym}':curr_price,
                f'RSI_short_{sym}':RSI_short,
                f'RSI_long_{sym}':RSI_long,
                f'pre_RSI_short_{sym}':pre_RSI_short,
                f'pre_RSI_long_{sym}':pre_RSI_long,
                f'buy_{sym}':buy,
                f'sell_{sym}':sell
            }
        )
        #if pre_RSI_short and
        
        if stock_position == 0 :
            if (RSI_short <= 30) and (pre_RSI_long > pre_RSI_short) and (RSI_short > RSI_long)  and (cash_position >= curr_price * 1000):
                order(i, 1000)
                buy = True
                record(
                    **{
                        f'buy_{sym}':buy
                    }
                )
            else:
                pass
        elif stock_position > 0  :
            if (RSI_short > 45) and (RSI_short < 55) and (pre_RSI_long > pre_RSI_short) and (RSI_short > RSI_long) and (cash_position >= curr_price * 1000):
                order(i, 1000)
                buy = True
                record(
                    **{
                        f'buy_{sym}':buy
                    }
                )
            elif (RSI_short >= 70) and(pre_RSI_short > pre_RSI_long) and (RSI_long > RSI_short) and (stock_position > 0):
                order_target(i, 0)
                sell = True
                record(
                    **{
                        f'sell_{sym}':sell
                    }
                )
            else:
                pass
        else:
            pass

# %%
def analyze(context, perf):
    pass

# %%
from zipline import run_algorithm
start_d=pd.Timestamp('2021-01-25',tz='utc')
results = run_algorithm(
    start = start_d,
    end = end_date,
    initialize=initialize,
    bundle='tquant',
    analyze=analyze,
    capital_base=5e6,
    handle_data = handle_data
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\exchange_calendars\utils\memoize.py:47, in lazyval.__get__(self, instance, owner)
#      46 try:
# ---> 47     return self._cache[instance]
#      48 except KeyError:
#
# File ~\anaconda3\envs\zipline-tej\Lib\weakref.py:415, in WeakKeyDictionary.__getitem__(self, key)
#     414 def __getitem__(self, key):
# --> 415     return self.data[ref(key)]
#
# KeyError: <weakref at 0x00000128AF3D7600; to 'BcolzMinuteBarReader' at 0x00000128AF367690>
#
# During handling of the above exception, another exception occurred:
#
# NotSessionError                           Traceback (most recent call last)
# Cell In[230], line 3
#       1 from zipline import run_algorithm
#       2 start_d=pd.Timestamp('2021-01-25',tz='utc')
# ----> 3 results = run_algorithm(
#       4     start = start_d,
#       5     end = end_date,
#       6     initialize=initialize,
#       7     bundle='tquant',
#       8     analyze=analyze,
#       9     capital_base=5e6,
#      10     handle_data = handle_data
#      11 )
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\utils\run_algo.py:483, in run_algorithm(start, end, initialize, capital_base, handle_data, before_trading_start, analyze, data_frequency, bundle, bundle_timestamp, trading_calendar, metrics_set, benchmark_returns, treasury_returns, default_extension, extensions, strict_extensions, environ, custom_loader, blotter)
#     480 benchmark_spec = BenchmarkSpec.from_returns(benchmark_returns)
#     481 treasury_spec = TreasurySpec.from_returns(treasury_returns)    #20230210(by MRC) for treasury return column in perf
# --> 483 return _run(
#     484     handle_data=handle_data,
#     485     initialize=initialize,
#     486     before_trading_start=before_trading_start,
#     487     analyze=analyze,
#     488     algofile=None,
#     489     algotext=None,
#     490     defines=(),
#     491     data_frequency=data_frequency,
#     492     capital_base=capital_base,
#     493     bundle=bundle,
#     494     bundle_timestamp=bundle_timestamp,
#     495     start=start,
#     496     end=end,
#     497     output=os.devnull,
#     498     trading_calendar=trading_calendar,
#     499     print_algo=False,
#     500     metrics_set=metrics_set,
#     501     local_namespace=False,
#     502     environ=environ,
#     503     blotter=blotter,
#     504     custom_loader=custom_loader,
#     505     benchmark_spec=benchmark_spec,
#     506     treasury_spec=treasury_spec           #20230209 (by MRC) for treasury return column in perf
#     507 )
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\utils\run_algo.py:196, in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, environ, blotter, custom_loader, benchmark_spec, treasury_spec)
#     192         click.echo(algotext)
#     194 first_trading_day = bundle_data.equity_minute_bar_reader.first_trading_day
# --> 196 data = DataPortal(
#     197     bundle_data.asset_finder,
#     198     trading_calendar=trading_calendar,
#     199     first_trading_day=first_trading_day,
#     200     equity_minute_reader=bundle_data.equity_minute_bar_reader,
#     201     equity_daily_reader=bundle_data.equity_daily_bar_reader,
#     202     adjustment_reader=bundle_data.adjustment_reader,
#     203     future_minute_reader=bundle_data.equity_minute_bar_reader,
#     204     future_daily_reader=bundle_data.equity_daily_bar_reader,
#     205 )
#     207 pipeline_loader = USEquityPricingLoader.without_fx(
#     208     bundle_data.equity_daily_bar_reader,
#     209     bundle_data.adjustment_reader,
#     210 )
#     212 sids = bundle_data.asset_finder.equities_sids
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\data\data_portal.py:209, in DataPortal.__init__(self, asset_finder, trading_calendar, first_trading_day, equity_daily_reader, equity_minute_reader, future_daily_reader, future_minute_reader, adjustment_reader, last_available_session, last_available_minute, minute_history_prefetch_length, daily_history_prefetch_length)
#     206     self._last_available_minute = last_available_minute
#     207 else:
#     208     # Infer the last minute from the provided readers.
# --> 209     last_minutes = [
#     210         reader.last_available_dt
#     211         for reader in [equity_minute_reader, future_minute_reader]
#     212         if reader is not None
#     213     ]
#     214     if last_minutes:
#     215         self._last_available_minute = max(last_minutes)
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\data\data_portal.py:210, in <listcomp>(.0)
#     206     self._last_available_minute = last_available_minute
#     207 else:
#     208     # Infer the last minute from the provided readers.
#     209     last_minutes = [
# --> 210         reader.last_available_dt
#     211         for reader in [equity_minute_reader, future_minute_reader]
#     212         if reader is not None
#     213     ]
#     214     if last_minutes:
#     215         self._last_available_minute = max(last_minutes)
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\exchange_calendars\utils\memoize.py:49, in lazyval.__get__(self, instance, owner)
#      47     return self._cache[instance]
#      48 except KeyError:
# ---> 49     self._cache[instance] = val = self._get(instance)
#      50     return val
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\data\minute_bars.py:953, in BcolzMinuteBarReader.last_available_dt(self)
#     951 @lazyval
#     952 def last_available_dt(self):
# --> 953     _, close = self.calendar.open_and_close_for_session(self._end_session)
#     954     return close
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\exchange_calendars\exchange_calendar.py:1083, in ExchangeCalendar.open_and_close_for_session(self, session_label)
#    1066 def open_and_close_for_session(
#    1067     self, session_label: Session
#    1068 ) -> tuple(pd.Timestamp, pd.Timestamp):
#    1069     """
#    1070     Returns a tuple of timestamps of the open and close of the session
#    1071     represented by the given label.
#    (...)
#    1081         The open and close for the given session.
#    1082     """
# -> 1083     session_label = parse_session(self, session_label, "session_label")
#    1084     return (
#    1085         self.session_open(session_label),
#    1086         self.session_close(session_label),
#    1087     )
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\exchange_calendars\calendar_helpers.py:277, in parse_session(calendar, session, param_name)
#     274 # don't check via is_session to allow for more specific error message if
#     275 # `session` is out-of-bounds
#     276 if ts not in calendar.schedule.index:
# --> 277     raise errors.NotSessionError(calendar, ts, param_name)
#     278 return ts
#
# NotSessionError: Parameter `session_label` takes a session label although received input that parsed to '2024-06-11 00:00:00+00:00' which is later than the last session of calendar 'TEJ_XTAI' ('2024-06-07 00:00:00+00:00').

# %%
results
# Out:
#                                         period_open              period_close  \
# 2021-01-25 13:30:00+08:00 2021-01-25 09:01:00+08:00 2021-01-25 13:30:00+08:00
# 2021-01-26 13:30:00+08:00 2021-01-26 09:01:00+08:00 2021-01-26 13:30:00+08:00
# 2021-01-27 13:30:00+08:00 2021-01-27 09:01:00+08:00 2021-01-27 13:30:00+08:00
# 2021-01-28 13:30:00+08:00 2021-01-28 09:01:00+08:00 2021-01-28 13:30:00+08:00
# 2021-01-29 13:30:00+08:00 2021-01-29 09:01:00+08:00 2021-01-29 13:30:00+08:00
# ...                                             ...                       ...
# 2023-12-25 13:30:00+08:00 2023-12-25 09:01:00+08:00 2023-12-25 13:30:00+08:00
# 2023-12-26 13:30:00+08:00 2023-12-26 09:01:00+08:00 2023-12-26 13:30:00+08:00
# 2023-12-27 13:30:00+08:00 2023-12-27 09:01:00+08:00 2023-12-27 13:30:00+08:00
# 2023-12-28 13:30:00+08:00 2023-12-28 09:01:00+08:00 2023-12-28 13:30:00+08:00
# 2023-12-29 13:30:00+08:00 2023-12-29 09:01:00+08:00 2023-12-29 13:30:00+08:00
#
#                            starting_exposure transactions  short_value  \
# 2021-01-25 13:30:00+08:00                0.0           []          0.0
# 2021-01-26 13:30:00+08:00                0.0           []          0.0
# 2021-01-27 13:30:00+08:00                0.0           []          0.0
# 2021-01-28 13:30:00+08:00                0.0           []          0.0
# 2021-01-29 13:30:00+08:00                0.0           []          0.0
# ...                                      ...          ...          ...
# 2023-12-25 13:30:00+08:00                0.0           []          0.0
# 2023-12-26 13:30:00+08:00                0.0           []          0.0
# 2023-12-27 13:30:00+08:00                0.0           []          0.0
# 2023-12-28 13:30:00+08:00                0.0           []          0.0
# 2023-12-29 13:30:00+08:00                0.0           []          0.0
#
#                            starting_value  portfolio_value positions  \
# 2021-01-25 13:30:00+08:00             0.0        5000000.0        []
# 2021-01-26 13:30:00+08:00             0.0        5000000.0        []
# 2021-01-27 13:30:00+08:00             0.0        5000000.0        []
# 2021-01-28 13:30:00+08:00             0.0        5000000.0        []
# 2021-01-29 13:30:00+08:00             0.0        5000000.0        []
# ...                                   ...              ...       ...
# 2023-12-25 13:30:00+08:00             0.0        5000000.0        []
# 2023-12-26 13:30:00+08:00             0.0        5000000.0        []
# 2023-12-27 13:30:00+08:00             0.0        5000000.0        []
# 2023-12-28 13:30:00+08:00             0.0        5000000.0        []
# 2023-12-29 13:30:00+08:00             0.0        5000000.0        []
#
#                            longs_count  short_exposure  ...  \
# 2021-01-25 13:30:00+08:00            0             0.0  ...
# 2021-01-26 13:30:00+08:00            0             0.0  ...
# 2021-01-27 13:30:00+08:00            0             0.0  ...
# 2021-01-28 13:30:00+08:00            0             0.0  ...
# 2021-01-29 13:30:00+08:00            0             0.0  ...
# ...                                ...             ...  ...
# 2023-12-25 13:30:00+08:00            0             0.0  ...
# 2023-12-26 13:30:00+08:00            0             0.0  ...
# 2023-12-27 13:30:00+08:00            0             0.0  ...
# 2023-12-28 13:30:00+08:00            0             0.0  ...
# 2023-12-29 13:30:00+08:00            0             0.0  ...
#
#                            benchmark_period_return  excess_return  \
# 2021-01-25 13:30:00+08:00                -0.004525       0.004525
# 2021-01-26 13:30:00+08:00                -0.022485       0.022485
# 2021-01-27 13:30:00+08:00                -0.019825       0.019825
# 2021-01-28 13:30:00+08:00                -0.037652       0.037652
# 2021-01-29 13:30:00+08:00                -0.054980       0.054980
# ...                                            ...            ...
# 2023-12-25 13:30:00+08:00                 0.098995      -0.098995
# 2023-12-26 13:30:00+08:00                 0.108165      -0.108165
# 2023-12-27 13:30:00+08:00                 0.116890      -0.116890
# 2023-12-28 13:30:00+08:00                 0.118068      -0.118068
# 2023-12-29 13:30:00+08:00                 0.119344      -0.119344
#
#                            benchmark_volatility  price_6799  RSI_short_6799  \
# 2021-01-25 13:30:00+08:00                   NaN         NaN             NaN
# 2021-01-26 13:30:00+08:00              0.151713         NaN             NaN
# 2021-01-27 13:30:00+08:00              0.167275         NaN             NaN
# 2021-01-28 13:30:00+08:00              0.164593         NaN             NaN
# 2021-01-29 13:30:00+08:00              0.154780         NaN             NaN
# ...                                         ...         ...             ...
# 2023-12-25 13:30:00+08:00              0.168754       182.5       80.952381
# 2023-12-26 13:30:00+08:00              0.168705       175.5       71.830986
# 2023-12-27 13:30:00+08:00              0.168648       181.0       75.000000
# 2023-12-28 13:30:00+08:00              0.168531       185.5       83.132530
# 2023-12-29 13:30:00+08:00              0.168413       194.0       83.529412
#
#                            RSI_long_6799  pre_RSI_short_6799  \
# 2021-01-25 13:30:00+08:00            NaN                 NaN
# 2021-01-26 13:30:00+08:00            NaN                 NaN
# 2021-01-27 13:30:00+08:00            NaN                 NaN
# 2021-01-28 13:30:00+08:00            NaN                 NaN
# 2021-01-29 13:30:00+08:00            NaN                 NaN
# ...                                  ...                 ...
# 2023-12-25 13:30:00+08:00      74.226804                 NaN
# 2023-12-26 13:30:00+08:00      66.666667                 NaN
# 2023-12-27 13:30:00+08:00      70.940171                 NaN
# 2023-12-28 13:30:00+08:00      67.619048                 NaN
# 2023-12-29 13:30:00+08:00      72.727273                 NaN
#
#                            pre_RSI_long_6799  buy_6799 sell_6799
# 2021-01-25 13:30:00+08:00                NaN       NaN       NaN
# 2021-01-26 13:30:00+08:00                NaN       NaN       NaN
# 2021-01-27 13:30:00+08:00                NaN       NaN       NaN
# 2021-01-28 13:30:00+08:00                NaN       NaN       NaN
# 2021-01-29 13:30:00+08:00                NaN       NaN       NaN
# ...                                      ...       ...       ...
# 2023-12-25 13:30:00+08:00                NaN     False     False
# 2023-12-26 13:30:00+08:00                NaN     False     False
# 2023-12-27 13:30:00+08:00                NaN     False     False
# 2023-12-28 13:30:00+08:00                NaN     False     False
# 2023-12-29 13:30:00+08:00                NaN     False     False
#
# [714 rows x 165 columns]

# %%
results.returns.cumsum().plot()
# Out:
# <Axes: >

# %%
type(results)
# Out:
# pandas.core.frame.DataFrame
